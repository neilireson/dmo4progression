# %%
#####################################################
# imports
#####################################################

import numpy as np
import os
import pandas as pd
import seaborn as sns

from collections import ChainMap, defaultdict

from dotenv import load_dotenv

from imblearn.over_sampling import ADASYN, SMOTE, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

from joblib import Parallel, delayed

from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs

from scipy.cluster import hierarchy
from scipy.spatial.distance import squareform
from scipy.stats import spearmanr

from sklearn import set_config
from sklearn.decomposition import PCA
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, RandomForestRegressor
from sklearn.feature_selection import SelectFromModel, mutual_info_classif, RFECV, SequentialFeatureSelector
from sklearn.inspection import permutation_importance
from sklearn.linear_model import LogisticRegression, RidgeCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_score, \
    recall_score
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.utils.class_weight import compute_sample_weight

from skopt import BayesSearchCV
from skopt.space import Categorical, Integer, Real

from timeit import default_timer as timer

from xgboost import XGBClassifier

import matplotlib.colors as colors
import matplotlib.pyplot as plt

# make transform operations return dataframes
set_config(transform_output="pandas")

# remove dtype from printing
np.set_printoptions(legacy='1.25')

# %%
#####################################################
# Experimental Parameters
#
#####################################################

# data preparation
min_prev_score = 2.5
score_threshold = 5.0
min_progression = 0.5

# feature selection
mi_threshold = 0.0
feature_selection_type = None
show_feature_analysis = True
show_mi_feature_selection = True
show_cluster_feature_selection = True
show_pca_feature_selection = True
show_rfe_feature_selection = True
show_sfs_feature_selection = True

drop_DMO_features = False
drop_non_DMO_features = True

# number of parallel jobs to run
# if n_jobs <0, the actual n_jobs is n_cpus + 1 + n_jobs
fs_n_jobs = -2

# undersampling
do_data_sampling = False

# hyper parameter search
n_iter = 20
random_state = 42
verbose = 0
hps_n_jobs = -2
cv = 5
scoring = 'recall_macro'

# cross validation
cv_folds = 5

show_data_distributions = False

# where to save figures:
fig_save_dir = "../figures/"
if drop_DMO_features:
    fig_save_dir = fig_save_dir + "no_dmo_features/"
elif drop_non_DMO_features:
    fig_save_dir = fig_save_dir + "dmo_features/"
else:
    fig_save_dir = fig_save_dir + "all_features/"

os.makedirs(fig_save_dir, exist_ok=True)

# %%
#####################################################
# Data preparation and exclusion
#
#####################################################

# get variables from .env, e.g. DATA_DIR
load_dotenv()

def show_transition_matrix(name):
    # Create matrix of prev -> next EDSS scores
    prev_scores = data['Prev_EDSS'].to_numpy().tolist()
    next_scores = data['EDFSCR1L'].to_numpy().tolist()

    # extract the unique scores
    scores = list(set(prev_scores).union(set(next_scores)))
    scores.sort()
    n_scores = len(scores)

    # Create transition matrix
    # Note some of these transitions will be for people with missing DMOs
    transition_matrix = pd.DataFrame(
        np.zeros((n_scores, n_scores), dtype=int),
        index=scores,
        columns=scores)

    for prev_score, next_score in zip(prev_scores, next_scores):
        transition_matrix.loc[prev_score, next_score] += 1

    # Pretty print transition matrix as heatmap
    plt.subplots(figsize=(10, 8))
    ax = plt.subplot(111)
    sns.heatmap(transition_matrix.values, annot=True, cmap="Blues", ax=ax, fmt='d', norm=colors.LogNorm())
    ax.set_xlabel('Next Score')
    ax.set_ylabel('Previous Score')
    ax.xaxis.set_ticklabels(scores)
    ax.yaxis.set_ticklabels(scores)
    plt.savefig("../figures/"+name+".png")
    plt.show()

data_dir = os.getenv("DATA_DIR", "Dataset/")

# read in main MS dataset
data_file_path = data_dir + r"MS_dataset_v.7.3.csv"
cols_from_dataset = ['Local.Participant', 'EDFSCR1L', 'visit.number', 'age', 'gender', 'mstypeonset', 'mstypediag',
                     'visit.date']
data = pd.read_csv(data_file_path, usecols=cols_from_dataset)

# forward fill within groups to ensure no leakage of demographics between participants
cols_from_dataset = [col for col in cols_from_dataset if col in ['age', 'gender', 'mstypeonset', 'mstypediag']]
for col in cols_from_dataset:
    data[col] = data.groupby('Local.Participant')[col].ffill()

# we need to get the time difference and convert from timedelta to something that the ML models can use - probably unix time
data['time_since_diag'] = (pd.to_datetime(data['visit.date']) - pd.to_datetime(data['mstypediag'])).dt.total_seconds()
data['time_since_onset'] = (pd.to_datetime(data['visit.date']) - pd.to_datetime(data['mstypeonset'])).dt.total_seconds()

# drop cols used for calculation
data = data.drop(['mstypeonset', 'mstypediag', 'visit.date'], axis=1)

# convert gender to 0 and 1
data['gender'] = data['gender'].map({'Male': 0, 'Female': 1})

# Crop down to just the necessary columns
data = data.sort_values(by=['Local.Participant', 'visit.number'])

# shift timepoints and EDSS to get previous as columns
data['Prev_EDSS'] = data.groupby('Local.Participant')['EDFSCR1L'].shift(1)
data['Prev_Timepoint'] = data.groupby('Local.Participant')['visit.number'].shift(1)

# get progression label column
progression_mask = (
        (data['Prev_EDSS'] < score_threshold) &
        (data['EDFSCR1L'] >= score_threshold) &
        ((data['EDFSCR1L'] - data['Prev_EDSS']) >= min_progression)
)
data['progression'] = np.where(progression_mask, 1, 0)

transitions = data[progression_mask]  # all the data where a transition happens, just in case.

data['Prev_Timepoint'] = data['Prev_Timepoint'].str.upper()  # needed for later merges
data['visit.number'] = data['visit.number'].str.upper()  # this one is just for consistency

#display(transitions.head(10))

# now that we have a reduced dataset, loop through our weekly dmo aggregations and append the relevant ones to the dataframe
timepoints = ["T1", "T2", "T3", "T4"]  # we don't need DMOs where T5 is previous

dfs_list = []
for timepoint in timepoints:
    feature_file_path = data_dir + f"/{timepoint} Aggregated DMO Data_V7.3/cvs-{timepoint}-weekly_agg_all-21-01-2026.csv"
    temp_df = pd.read_csv(feature_file_path)
    dfs_list.append(temp_df)

features_df = pd.concat(dfs_list, ignore_index=True)
data = pd.merge(data, features_df, left_on=['Local.Participant', 'Prev_Timepoint'],
                right_on=['participant_id', 'visit_type'], how='left')

data = data.drop(['participant_id', 'visit_type'], axis=1)
data = data.dropna(subset=['Prev_Timepoint'])

# Data cleaning - will monitor number of rows throughout
print(f"Initially {len(data)} rows.")

# get rid of participants where either current or previous EDSS is missing
count_before = len(data)
data = data.dropna(subset=['EDFSCR1L', 'Prev_EDSS'])
print(f"{count_before - len(data)} rows have missing EDSS values and will be dropped...")

show_transition_matrix("all_transitions")

# Exclude participants with Prev_EDSS >= threshold as they have already progressed:
count_before = len(data)
high_prev_edss_mask = (data['Prev_EDSS'] >= score_threshold)
print(f"{sum(high_prev_edss_mask)} rows have a previous EDSS >= {score_threshold} and will be dropped...")
data = data.drop(data[high_prev_edss_mask].index)

# Exclude participants with Prev_EDSS < min_prev_score as they are highly unlikely to progress, and may have different mobility patterns
count_before = len(data)
low_prev_edss_mask = (data['Prev_EDSS'] < min_prev_score)
print(f"{sum(low_prev_edss_mask)} rows have a previous EDSS < {min_prev_score} and will be dropped...")
data = data.drop(data[low_prev_edss_mask].index)

# drop all remaining NAN rows, which will be due to missing DMOs
count_before = len(data)
data = data.dropna()
print(f"{count_before - len(data)} rows have missing DMOs and will be dropped...")

num_progressions = len(data[data["progression"] == 1])
unique_sub_progressions = len(data[data["progression"] == 1]['Local.Participant'].unique())

print(
    f"We have {num_progressions} progressions across {unique_sub_progressions} subjects, out of a total of {len(data)} valid samples.")

display(data[data["progression"] == 1].head(5))

# drop irrelevant or 'cheating' columns
y_data = data["progression"].reset_index(drop=True)  # can be data["progression"] or data["multiclass_progression"]
labels_X_all = data.reset_index(drop=True)

if (drop_DMO_features):
    X_data = data[['Prev_EDSS', 'age', 'gender', 'time_since_diag', 'time_since_onset']].reset_index(drop=True)
else:
    features_to_drop = ["progression", "Local.Participant", "EDFSCR1L", "visit.number", "Prev_Timepoint"]
    if (drop_non_DMO_features):
        features_to_drop += ['Prev_EDSS', 'age', 'gender', 'time_since_diag', 'time_since_onset']
    X_data = data.drop(features_to_drop, axis=1)

show_transition_matrix("trimmed_transitions")
#labels_df.to_csv("data.csv", index=False)

# need to be at least 1 (not 0.5) to change
# subset of EDSS and normalise?
# balance dataset - Done very good

# undersampled_df = labels_df.groupby('progression').sample(labels_df.groupby('progression').size().min())
# Out:
# Initially 2274 rows.
# 596 rows have missing EDSS values and will be dropped...
# 886 rows have a previous EDSS >= 5.0 and will be dropped...
# 60 rows have a previous EDSS < 2.5 and will be dropped...
# 39 rows have missing DMOs and will be dropped...
# We have 63 progressions across 58 subjects, out of a total of 693 valid samples.
#      Local.Participant visit.number   age  gender  EDFSCR1L  time_since_diag  \
# 29               10382           T2  61.0       1       6.0     1.272356e+09
# 46               10385           T4  41.0       0       6.0     3.045996e+08
# 74               10393           T2  45.0       1       5.0     2.581911e+08
# 77               10393           T5  46.0       1       6.0     3.052772e+08
# 213              21138           T3  41.0       1       5.0     6.981414e+08
#
#      time_since_onset  Prev_EDSS Prev_Timepoint  progression  ...  \
# 29       1.287476e+09        4.0             T1            1  ...
# 46       3.656844e+08        4.5             T3            1  ...
# 74       8.310231e+08        4.0             T1            1  ...
# 77       8.781092e+08        4.5             T4            1  ...
# 213      6.981414e+08        3.0             T2            1  ...
#
#      ws_30_avg_w  strlen_30_avg_w  cadence_30_avg_w  strdur_30_avg_w  \
# 29          0.84            106.0              94.0             1.25
# 46          0.96            116.0              98.0             1.16
# 74          0.83            118.0              84.0             1.35
# 77          0.86            120.0              84.0             1.34
# 213         0.83            111.0              88.0             1.28
#
#      ws_30_p90_w  cadence_30_p90_w  ws_30_var_w  strlen_30_var_w  wb_60_sum_w  \
# 29          1.00             103.0         17.0             16.0          7.0
# 46          1.12             109.0         18.0             14.0         10.0
# 74          1.03              98.0         19.0             13.0          3.0
# 77          1.07             100.0         19.0             11.0          4.0
# 213         0.97              95.0         19.0             14.0          2.0
#
#      n_days_w
# 29        7.0
# 46        7.0
# 74        7.0
# 77        7.0
# 213       7.0
#
# [5 rows x 35 columns]

# %%
#####################################################
# Data normalisation
#
#####################################################

# Data normalisation (Note the impact of this needs to be tested)
# e.g. StandardScaler, MinMaxScaler, RobustScaler
# If columns have different (e.g. skewed) distributions that may need different normalisations
# e.g. Log normalisation
# Note that StandardScaler is generally preferred,
# however combined with small data will hang SVC, while MinMaxScaler works
scaler = MinMaxScaler()

if (show_data_distributions):
    for i, column in enumerate(X_data.columns):
        if (X_data[column].dtype == 'float64'):
            sns.displot(data=X_data, x=column, kind="kde")
        else:
            sns.displot(X_data, x=column)

# %%
######################################################################
# Machine learning models
#
######################################################################

# Note need to remove 'poly' as an option from the SVC kernel to make it work on small data sets.
# See https://github.com/scikit-learn/scikit-learn/issues/4648
svm_model = BayesSearchCV(
    SVC(random_state=42),
    {
        'C': Real(1e-6, 1e+6, prior='log-uniform'),  # Regularization parameter
        'gamma': Real(1e-6, 1e+1, prior='log-uniform'),  # Kernel coefficient
        'kernel': Categorical(['rbf', 'sigmoid']),  # Type of kernel
        'degree': Integer(1, 5)  # Degree for poly kernel
    },
    n_iter=n_iter,
    random_state=random_state,
    verbose=verbose,
    n_jobs=hps_n_jobs,
    cv=cv,
    scoring=scoring
)

mlp_model = BayesSearchCV(
    MLPClassifier(random_state=random_state, max_iter=1000),
    {
        'hidden_layer_sizes': Integer(1, 128),  # Different architectures
        'activation': Categorical(['tanh', 'relu']),
        'solver': Categorical(['sgd', 'adam']),
        'alpha': Real(1e-5, 1e-1, prior='log-uniform'),  # L2 penalty (regularization)
        'learning_rate': Categorical(['constant', 'adaptive']),
        'learning_rate_init': Real(1e-4, 1e-1, prior='log-uniform')  # Initial learning rate
    },
    n_iter=n_iter,
    random_state=random_state,
    verbose=verbose,
    n_jobs=hps_n_jobs,
    cv=cv,
    scoring=scoring
)

knn_model = BayesSearchCV(
    KNeighborsClassifier(),
    {
        'n_neighbors': Integer(1, 50),
        'weights': Categorical(['uniform', 'distance']),
        'algorithm': Categorical(['auto', 'ball_tree', 'kd_tree', 'brute']),
        'leaf_size': Integer(10, 50),
        'p': Integer(1, 2)  # 1 = Manhattan, 2 = Euclidean distance
    },
    n_iter=n_iter,
    random_state=random_state,
    verbose=verbose,
    n_jobs=hps_n_jobs,
    cv=cv,
    scoring=scoring
)

xgb_model = BayesSearchCV(
    XGBClassifier(random_state=random_state, use_label_encoder=False, eval_metric='logloss'),
    {
        'n_estimators': Integer(50, 500),
        'max_depth': Integer(3, 10),
        'learning_rate': Real(0.01, 1.0, prior='log-uniform'),
        'subsample': Real(0.5, 1.0, prior='uniform'),  # Fraction of samples used for fitting
        'colsample_bytree': Real(0.5, 1.0, prior='uniform'),  # Fraction of features used per tree
        'gamma': Real(1e-6, 5, prior='log-uniform'),  # Min loss reduction for split
        'reg_alpha': Real(1e-5, 10, prior='log-uniform'),  # L1 regularization
        'reg_lambda': Real(1e-5, 10, prior='log-uniform')  # L2 regularization
    },
    n_iter=n_iter,
    random_state=random_state,
    verbose=verbose,
    n_jobs=hps_n_jobs,
    cv=cv,
    scoring=scoring
)

rf_model = BayesSearchCV(
    RandomForestClassifier(random_state=random_state),
    {
        'n_estimators': Integer(50, 500),
        'max_depth': Integer(5, 50),
        'min_samples_split': Integer(2, 20),
        'min_samples_leaf': Integer(1, 10),
        'max_features': Categorical(['sqrt', 'log2', None]),  # Number of features to consider at each split
        'bootstrap': Categorical([True, False]),
        'criterion': Categorical(['gini', 'entropy'])
    },
    n_iter=n_iter,
    random_state=random_state,
    verbose=verbose,
    n_jobs=hps_n_jobs,
    cv=cv,
    scoring=scoring
)

dt_model = BayesSearchCV(
    DecisionTreeClassifier(random_state=random_state),
    {
        'criterion': Categorical(['gini', 'entropy']),
        'max_depth': Integer(3, 30),
        'min_samples_split': Integer(2, 20),
        'min_samples_leaf': Integer(1, 20),
        'max_features': Categorical(['sqrt', 'log2', None]),
        'ccp_alpha': Real(0.0, 0.1, prior='uniform')  # Cost-Complexity Pruning alpha
    },
    n_iter=n_iter,
    random_state=random_state,
    verbose=verbose,
    n_jobs=hps_n_jobs,
    cv=cv,
    scoring=scoring
)

lr_model = BayesSearchCV(
    LogisticRegression(random_state=random_state, solver='saga', max_iter=5000),
    {
        'C': Real(1e-6, 1e+6, prior='log-uniform'),  # Inverse of regularization strength
        'penalty': Categorical(['l1', 'l2', 'elasticnet']),
        'l1_ratio': Real(0, 1, prior='uniform'),  # Only used if penalty='elasticnet'
        'fit_intercept': Categorical([True, False])
    },
    n_iter=n_iter,
    random_state=random_state,
    verbose=verbose,
    n_jobs=hps_n_jobs,
    cv=cv,
    scoring=scoring
)

# %%
###################################################################
# Utility functions for cross-validation and results
###################################################################

def do_cv(model, X_data, y_data, n_splits=cv_folds, random_state=42, quiet=False):
    # requires: set_config(transform_output="pandas")
    # transformer = ColumnTransformer([('standard_scaler', ss, feature_cols)],
    #                                 remainder='passthrough',
    #                                 verbose_feature_names_out=False)

    combined_cm = None
    combined_y_test = None
    combined_y_pred = None
    kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    for i, (train_split_indices, test_split_indices) in enumerate(kf.split(X_data, y_data)):

        X_train_split = X_data.iloc[train_split_indices]
        X_test_split = X_data.iloc[test_split_indices]
        y_train_split = y_data.iloc[train_split_indices]
        y_test_split = y_data.iloc[test_split_indices]

        X_train_scaled = scaler.fit_transform(X_train_split)
        X_test_scaled = scaler.transform(X_test_split)

        # sample weighting
        sample_weights = compute_sample_weight(class_weight='balanced', y=y_train_split)

        # we need this to deal with the KNN not accepting sample weights
        try:
            model.fit(X_train_scaled, y_train_split, sample_weight=sample_weights)
        except Exception as e:
            print("Sample weighting not accepted, training without... ")
            print(e)
            model.fit(X_train_scaled, y_train_split)
        y_pred = model.predict(X_test_scaled)

        if not quiet:
            print(f"Fold {i}")
            print(f"accuracy: {accuracy_score(y_test_split, y_pred):.2f}")
            print(f"precision_macro: {precision_score(y_test_split, y_pred, average='macro', zero_division=0):.2f}")
            print(f"recall_macro: {recall_score(y_test_split, y_pred, average='macro', zero_division=0):.2f}")
            print(f"f1_macro: {f1_score(y_test_split, y_pred, average='macro', zero_division=0):.2f}")

        cm = confusion_matrix(y_test_split, y_pred)
        # turn y_pred into a series
        y_pred_series = pd.Series(y_pred, index=y_test_split.index)
        combined_cm = cm if combined_cm is None else combined_cm + cm
        combined_y_test = y_test_split if combined_y_test is None else pd.concat([combined_y_test, y_test_split])
        combined_y_pred = y_pred_series if combined_y_pred is None else pd.concat([combined_y_pred, y_pred_series])

    return combined_cm, combined_y_test, combined_y_pred


# ToDo make generic, i.e. anle to handle different sized CM
def display_cm(cm, fig_name = None):
    # Pretty print confusion matrix
    ax = plt.subplot()

    cm = pd.DataFrame(cm, range(2), range(2))
    sns.heatmap(cm, annot=True, cmap="Blues", ax=ax, fmt='d')

    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')
    ax.xaxis.set_ticklabels(['0', '1'])
    ax.yaxis.set_ticklabels(['0', '1'])
    if not fig_name == None:
        plt.title(fig_name)
        plt.savefig(fig_save_dir+fig_name)
    plt.show()


def show_evaluation(model, X_test, y_test, fig_name = None):
    y_pred = model.predict(X_test)

    print(f"accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))

    cm = confusion_matrix(y_test, y_pred)

    display_cm(cm, fig_name)


def get_metrics_from_cm(cm):
    tn, fp, fn, tp = cm.ravel()

    accuracy = (tp + tn) / (tp + tn + fp + fn)
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1": f1_score
    }


def get_metrics_from_prediction(actual, predicted):
    return {
        "accuracy": accuracy_score(actual, predicted),
        "precision": precision_score(actual, predicted),
        "recall": recall_score(actual, predicted),
        "f1": f1_score(actual, predicted),
        "precision_macro": precision_score(actual, predicted, average='macro', zero_division=0),
        "recall_macro": recall_score(actual, predicted, average='macro', zero_division=0),
        "f1_macro": f1_score(actual, predicted, average='macro', zero_division=0),
    }

# %%
###################################################################
# Feature selection and exclusion
# Note that in data preparation rows with NaN values are excluded.
# Removing these features (columns) may increase the data,
# if that feature is the reason for NaN exclusion.
# ToDo Test with various thresholds
###################################################################


def rf_feature_analysis(X, y, random_state=42):
    model = RandomForestRegressor(random_state=random_state)
    model.fit(X, y)

    # The importance of a feature is how much this feature is used in each tree of the forest.
    # It is computed as the (normalized) total reduction of the criterion brought by that feature.
    std = np.std([tree.feature_importances_ for tree in model.estimators_], axis=0)

    fig, ax = plt.subplots()
    importances = pd.Series(model.feature_importances_, index=np.array(X.columns))
    importances = pd.Series(data=importances, index=X.columns).sort_values(ascending=False)
    importances.plot.bar(yerr=std, ax=ax)
    ax.set_title("Feature importance using MDI")
    ax.set_ylabel("Mean decrease in impurity")
    fig.tight_layout()


def rf_perm_feature_analysis(X, y, random_state=42):
    model = RandomForestClassifier(random_state=random_state)
    model.fit(X, y)

    result = permutation_importance(model, X, y, n_repeats=10, random_state=random_state, n_jobs=fs_n_jobs)

    fig, ax = plt.subplots()
    importances = pd.Series(result.importances_mean, index=np.array(X.columns))
    importances = pd.Series(data=importances, index=X.columns).sort_values(ascending=False)
    importances.plot.bar(yerr=result.importances_std, ax=ax)
    ax.set_title("Feature importance using permutation on full model")
    ax.set_ylabel("Mean accuracy decrease")
    fig.tight_layout()
    plt.savefig(fig_save_dir+"rm_perm_feature_analysis.png")
    plt.show()


def plot_permutation_importance(clf, X, y, ax, indexes=None, random_state=42):
    result = permutation_importance(clf, X, y, n_repeats=10, random_state=random_state, n_jobs=fs_n_jobs)
    if indexes is not None:
        perm_sorted_idx = indexes
    else:
        perm_sorted_idx = result.importances_mean.argsort()

    tick_labels_dict = {"tick_labels": X.columns[perm_sorted_idx]}
    ax.boxplot(result.importances[perm_sorted_idx].T, vert=False, **tick_labels_dict)
    ax.axvline(x=0, color="k", linestyle="--")
    return ax


def rf_combine_feature_analysis(X, y, random_state=42):
    clf = RandomForestClassifier(n_estimators=100, random_state=random_state)
    clf.fit(X, y)

    mdi_importances = pd.Series(clf.feature_importances_, index=X.columns)
    tree_importance_sorted_idx = np.argsort(clf.feature_importances_)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))
    mdi_importances.sort_values().plot.barh(ax=ax1)
    ax1.set_xlabel("Gini importance")
    plot_permutation_importance(clf, X, y, ax2, tree_importance_sorted_idx)
    ax2.set_xlabel("Decrease in accuracy score")
    fig.suptitle(
        "Impurity-based vs. permutation importance on multicollinear features (train set)"
    )
    _ = fig.tight_layout()
    plt.savefig(fig_save_dir+"rm_combined_feature_analysis.png")
    plt.show()


def mi_feature_selection(X, y, mi_threshold=0.0, random_state=42):
    # feature importance analysis
    pearson_corr = X.corrwith(y).sort_values(ascending=False)
    display(pearson_corr)

    # mutual information gain for feature removal
    mi = mutual_info_classif(X, y, random_state=random_state, n_jobs=fs_n_jobs)
    mi = pd.Series(data=mi, index=X.columns).sort_values(ascending=False)
    mi.plot(kind='bar')
    plt.title("Feature importance via mutual information")
    plt.savefig(fig_save_dir+"mi_feature_selection.png")
    plt.show()

    # delete features with 0 information gain
    mi = mi[mi > mi_threshold]

    X = X[mi.index]

    return X


# Feature importance from coefficients
def fi(X, y, model, threshold=0.0):
    model.fit(X, y)
    feature_names = np.array(X.columns)
    importance = pd.Series(data=np.abs(model.coef_), index=feature_names).sort_values(ascending=False)
    importance.plot(kind='bar')
    plt.title("Feature importance via coefficients: " + type(model).__name__)
    plt.savefig(fig_save_dir+"feature_importance_coeff.png")
    plt.show()

    sfm = SelectFromModel(model, threshold=threshold).fit(X, y)
    print(f"Features selected by SelectFromModel above threshold {threshold}: {feature_names[sfm.get_support()]}")


def show_correlation(X):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))
    corr = spearmanr(X).correlation

    # Ensure the correlation matrix is symmetric
    corr = (corr + corr.T) / 2
    np.fill_diagonal(corr, 1)

    # We convert the correlation matrix to a distance matrix before performing
    # hierarchical clustering using Ward's linkage.
    distance_matrix = 1 - np.abs(corr)
    dist_linkage = hierarchy.ward(squareform(distance_matrix))
    dendro = hierarchy.dendrogram(
        dist_linkage, labels=X.columns.to_list(), ax=ax1, leaf_rotation=90
    )
    dendro_idx = np.arange(0, len(dendro["ivl"]))

    ax2.imshow(corr[dendro["leaves"], :][:, dendro["leaves"]])
    ax2.set_xticks(dendro_idx)
    ax2.set_yticks(dendro_idx)
    ax2.set_xticklabels(dendro["ivl"], rotation="vertical")
    ax2.set_yticklabels(dendro["ivl"])
    _ = fig.tight_layout()
    plt.savefig(fig_save_dir+"spearman_correlation.png")
    plt.show()

    return dist_linkage


def cluster_selection(X, y, dist_linkage, threshold=0.05, random_state=42):
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=random_state, train_size=0.5)

    clf = RandomForestClassifier(n_estimators=100, random_state=random_state)
    clf.fit(X_train, y_train)
    print(f"Baseline accuracy on test data: {clf.score(X_test, y_test):.2}")

    cluster_ids = hierarchy.fcluster(dist_linkage, threshold, criterion="distance")
    cluster_id_to_feature_ids = defaultdict(list)
    for idx, cluster_id in enumerate(cluster_ids):
        cluster_id_to_feature_ids[cluster_id].append(idx)
    selected_features = [v[0] for v in cluster_id_to_feature_ids.values()]
    selected_features_names = X.columns[selected_features]

    X_train_sel = X_train[selected_features_names]
    X_test_sel = X_test[selected_features_names]

    clf_sel = RandomForestClassifier(n_estimators=100, random_state=random_state)
    clf_sel.fit(X_train_sel, y_train)
    print(
        "Baseline accuracy on test data with features removed:"
        f" {clf_sel.score(X_test_sel, y_test):.2}"
    )

    fig, ax = plt.subplots(figsize=(7, 6))
    plot_permutation_importance(clf_sel, X_test_sel, y_test, ax)
    ax.set_title("Permutation Importance on selected subset of features\n(test set)")
    ax.set_xlabel("Decrease in accuracy score")
    ax.figure.tight_layout()
    plt.savefig(fig_save_dir+"cluster_selection.png")
    plt.show()

    return X[selected_features_names]


def pca_selection(X, random_state=42):
    # normalisation
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    pca = PCA(n_components=0.95, svd_solver='full', random_state=random_state)  # keep 95% of variance
    X_pca = pd.DataFrame(data=pca.fit_transform(X_scaled))
    print("Explained variance:", pca.explained_variance_ratio_)
    print("Cumulative:", np.cumsum(pca.explained_variance_ratio_))
    print("Shape of Original Dataset:", X_scaled.shape)
    print("Shape after PCA:", X_pca.shape)

    loadings = pca.components_.T * np.sqrt(pca.explained_variance_)
    plt.figure(figsize=(10, 8))
    sns.heatmap(loadings, annot=True, cmap='coolwarm', yticklabels=np.array(X.columns))
    plt.title('Feature Importance in Principal Components')
    plt.savefig(fig_save_dir+"pca.png")
    plt.show()

    return X_pca


def get_rfecv(estimator, n_folds=5, scoring=scoring, min_features_to_select=3, n_jobs=fs_n_jobs):
    return RFECV(
        estimator=estimator,
        step=1,
        cv=StratifiedKFold(n_folds),
        scoring=scoring,
        min_features_to_select=min_features_to_select,
        n_jobs=n_jobs
    )


# Recursive Feature Elimination
def rfe(X, y, rfe_model):
    rfe_model.fit(X, y)

    print(f"Optimal number of features: {rfe_model.n_features_}")

    # summarize all features
    feature_names = np.array(X.columns)
    for i in range(X.shape[1]):
        print('%s, Selected %s, Rank: %d' % (feature_names[i], rfe_model.support_[i], rfe_model.ranking_[i]))

    rfe_data = {
        key: value
        for key, value in rfe_model.cv_results_.items()
        if key in ["n_features", "mean_test_score", "std_test_score"]
    }
    cv_results = pd.DataFrame(rfe_data)
    plt.figure()
    plt.xlabel("Number of features selected")
    plt.ylabel("Mean test " + scoring)
    plt.errorbar(
        x=cv_results["n_features"],
        y=cv_results["mean_test_score"],
        yerr=cv_results["std_test_score"],
    )
    plt.title("Recursive Feature Elimination \n" + rfe_model.estimator_.__class__.__name__)
    plt.savefig(fig_save_dir+"rfe.png")
    plt.show()

    return rfe_model.transform(X)


def rfe_test(X, y, model, random_state=42):
    # get a list of models to evaluate
    rfe_models = dict()
    # lr
    # rfe = get_rfecv(LogisticRegression())
    # models['lr'] = Pipeline(steps=[('s',rfe),('m',model)])
    # perceptron
    # rfe_models['per'] = get_rfecv(Perceptron())
    # cart
    rfe_models['dt'] = get_rfecv(DecisionTreeClassifier())
    # rf
    rfe_models['rf'] = get_rfecv(RandomForestClassifier())
    # gbm
    rfe_models['gbm'] = get_rfecv(GradientBoostingClassifier())

    # evaluate the models and store results
    # results, names = list(), list()
    for name, rfe_model in rfe_models.items():
        rfe_X = rfe(X, y, rfe_model)
        cm, actual, predicted = do_cv(model, rfe_X, y, random_state=random_state, quiet=True)
        print('>%s %s' % (name, rfe_X.shape))
        display(get_metrics_from_prediction(actual, predicted))

        # cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=random_state)
        # scores = cross_val_score(model, rfe_X, y, scoring='recall', cv=cv, n_jobs=-1)
        # results.append(scores)
        # names.append(name)
        # print(X.shape)
        # print(rfe_X.shape)
        # print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))
    # plot model performance for comparison
    # plt.boxplot(results, labels=names, showmeans=True)
    # plt.show()


def kv_table(kv, padding=5):
    if (len(kv) == 0):
        return
    # Get the longest subject name
    length = max(len(k) for k in kv)

    #use these two value to working out the exact space required
    space = length + padding

    #format and print the statement
    for key, value in kv.items():
        subject = "{0:{space}}".format(key, space=space)
        result = "{0:5f}".format(value['score'])
        print(subject + result)


def remove_feature(X_selected, y, feature_name, k_folds, model, random_state, scoring):
    new_X = X_selected.drop([feature_name], axis=1)
    cm, actual, predicted = do_cv(model, new_X, y, n_splits=k_folds, random_state=random_state, quiet=True)
    metrics = get_metrics_from_prediction(actual, predicted)
    return {feature_name: {"score": metrics[scoring], "cm": cm}}


def sfs(X, y, model, scoring='recall_macro', k_folds=5, n_jobs=fs_n_jobs, random_state=42):

    model_name = model.__class__.__name__
    if hasattr(model, 'estimator'):
        model_name += ": " + model.estimator.__class__.__name__

    # result with all features
    cm, actual, predicted = do_cv(model, X, y, n_splits=k_folds, random_state=random_state, quiet=True)
    print(f"Results for {model_name} for all {len(X.columns)} features")
    metrics = get_metrics_from_prediction(actual, predicted)
    display(metrics)

    best_feature_set = np.array(X.columns)
    best_score = metrics[scoring]

    all_results = []
    all_results.append({
        "n_features": len(X.columns),
        "features": np.array(X.columns),
        "score": best_score,
        "results": None,
    })

    X_selected = X
    while len(X_selected.columns) > 1:

        results = Parallel(n_jobs=n_jobs)(
            delayed(remove_feature)(X_selected, y, feature_name, k_folds, model, random_state, scoring)
            for feature_name in np.array(X_selected.columns))

        # change results into a dictionary and sort on score
        results = dict(ChainMap(*results))
        results = dict(sorted(results.items(), key=lambda item: item[1]['score'], reverse=True))
        print(f"Results from sequentially removing each feature from {len(X_selected.columns)} features")
        kv_table(results)
        # get first key which has the highest value, i.e. most beneficial to remove
        first_key = list(results.keys())[0]
        first_key_score = results[first_key]['score']
        print(f"Removing {first_key} feature from data. {scoring} = {first_key_score}")
        print(results[first_key]['cm'])
        if (first_key_score > best_score):
            best_feature_set = np.array(X_selected.columns)
            best_score = first_key_score

        X_selected = X_selected.drop([first_key], axis=1)
        all_results.append({
            "n_features": len(X_selected.columns),
            "features": np.array(X_selected.columns),
            "score": first_key_score,
            "results": results
        })

    print(f"Best feature set (size={len(best_feature_set)}): {best_feature_set}")
    print(f"Best score: {best_score}")

    x_axis = pd.DataFrame([item["n_features"] for item in all_results])
    y_axis = pd.DataFrame([item["score"] for item in all_results])

    plt.figure()
    plt.title(f"Feature Selection Results for {model_name}")
    plt.xlabel("Number of features selected")
    plt.ylabel(scoring)
    plt.plot(x_axis,y_axis)
    plt.savefig(fig_save_dir+"sfs.png")
    plt.show()

    return X[best_feature_set]


# I can not get this to work, it is unclear what I'm doing wrong.
# Thus I wrote my own (sfs) function above, as it's not complicated
def sfs1_test(X, y, model, scoring='recall_macro', k_folds=5, tols=None, n_jobs=fs_n_jobs, random_state=42):
    if tols is None:
        tols = [None]
    model_name = model.__class__.__name__

    feature_names = np.array(X.columns)

    cv = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=random_state)

    for tol in tols:
        print(f"Performing backward SFS for {model_name}, k_folds: {k_folds}, tol: {tol}...")
        start = timer()
        sfs = SequentialFeatureSelector(estimator=model,
                                        n_features_to_select="auto",
                                        direction="backward",
                                        tol=tol,
                                        n_jobs=n_jobs,
                                        scoring=scoring,
                                        cv=cv)
        end = timer()
        print(f"Finished in {end - start:.3f} seconds")
        sfs.fit(X, y)

        selected_features = feature_names[sfs.get_support()]
        print(
            f"Model {model_name}: tol {tol}: Selected {len(selected_features)}/{len(feature_names)} features: {selected_features}")

        X_selected = sfs.transform(X)
        cm, actual, predicted = do_cv(model, X_selected, y, n_splits=k_folds, random_state=random_state, quiet=True)
        metrics = get_metrics_from_prediction(actual, predicted)
        print(metrics)
        display_cm(cm)


# I can not get this to work, it is unclear what I'm doing wrong.
# Thus I wrote my own (sfs) function above, as it's not complicated
def sfs2_test(X, y, model, scoring='recall_macro', k_folds=5, n_jobs=fs_n_jobs, random_state=42):
    model_name = model.__class__.__name__

    # Define the stratified cross-validation strategy
    cv = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=random_state)

    print(f"Performing backward SFS for {model_name}, k_folds: {k_folds}...")
    start = timer()
    sfs = SFS(estimator=model,
              forward=False,
              floating=False,
              verbose=1,
              k_features="best",
              n_jobs=n_jobs,
              scoring=scoring,
              cv=cv)
    end = timer()
    print(f"Finished in {end - start:.3f} seconds")
    sfs.fit(X, y)
    print(f"CV Score: {sfs.k_score_}")

    print(sfs.subsets_)

    print(pd.DataFrame.from_dict(sfs.get_metric_dict()).T)

    plot_sfs(sfs.get_metric_dict(), kind='std_dev')
    plt.ylim([0, 1])
    plt.title('Sequential Forward Selection (w. StdDev)')
    plt.grid()
    plt.show()


if show_feature_analysis:
    # rf_feature_analysis(X_data, y_data)
    # rf_perm_feature_analysis(X_data, y_data)
    rf_combine_feature_analysis(X_data, y_data)

    ridge = RidgeCV(alphas=np.logspace(-6, 6, num=5))
    fi(X_data, y_data, ridge, threshold=0.0001)

if show_mi_feature_selection or feature_selection_type == "mi":
    # remove any feature with an MI pf 0
    X_data_mi = mi_feature_selection(X_data, y_data, mi_threshold=mi_threshold)

if show_cluster_feature_selection or feature_selection_type == "cluster":
    dist_linkage = show_correlation(X_data)
    X_data_cluster = cluster_selection(X_data, y_data, dist_linkage)

if show_pca_feature_selection or feature_selection_type == "pca":
    X_data_pca = pca_selection(X_data)

if show_rfe_feature_selection or feature_selection_type == "rfe":
    # xgb = XGBClassifier(random_state=random_state, use_label_encoder=False, eval_metric='logloss')
    # X_data_rfe = rfe(X_data, y_data, xgb)
    rfe_test(X_data, y_data, svm_model)

if show_sfs_feature_selection or feature_selection_type == "sfs":
    # ToDo we could optimise the feature set on all the machine learning models, this would take some time.
    # It would be good to have a measure of feature importance from SFS
    # model = SVC()
    X_data_sfs = sfs(X_data, y_data, svm_model, k_folds=cv_folds, random_state=random_state)

if feature_selection_type == "cluster":
    X_data = X_data_cluster
elif feature_selection_type == "mi":
    if (mi_threshold >= 0):
        X_data = X_data_mi
    else:
        print(f"Feature selection type 'mi', however mi_threshold is {mi_threshold}, so has no effect.")
elif feature_selection_type == "pca":
    X_data = X_data_pca
elif feature_selection_type == "sfs":
    X_data = X_data_sfs
# elif feature_selection_type == "rfe":
#     X_data = X_data_rfe
elif feature_selection_type is not None:
    print("Feature selection type not recognized")

print("Feature selection:", feature_selection_type)
print("X_data shape:", X_data.shape)
# Out:
# Features selected by SelectFromModel above threshold 0.0001: ['wb_all_sum_w' 'walkdur_all_sum_w' 'wbdur_all_avg_w' 'wbdur_all_p90_w'
#  'cadence_all_avg_w' 'strdur_all_avg_w' 'cadence_all_var_w'
#  'strdur_all_var_w' 'ws_1030_avg_w' 'strlen_1030_avg_w' 'wb_10_sum_w'
#  'ws_10_p90_w' 'wb_30_sum_w' 'strlen_30_avg_w' 'cadence_30_avg_w'
#  'strdur_30_avg_w' 'ws_30_p90_w' 'cadence_30_p90_w' 'ws_30_var_w'
#  'strlen_30_var_w' 'wb_60_sum_w' 'n_days_w']
# n_days_w             0.125936
# ws_1030_avg_w        0.116901
# cadence_all_avg_w    0.113037
# wb_all_sum_w         0.079582
# strdur_all_avg_w     0.076342
# cadence_all_var_w    0.073564
# cadence_30_p90_w     0.070122
# cadence_30_avg_w     0.059779
# strlen_1030_avg_w    0.055678
# wb_10_sum_w          0.054213
# walkdur_all_sum_w    0.050807
# wbsteps_all_sum_w    0.050612
# ws_30_avg_w          0.021403
# strdur_30_avg_w      0.021055
# ws_10_p90_w          0.012924
# strlen_30_avg_w      0.005638
# wbdur_all_var_w      0.002960
# wb_30_sum_w          0.002437
# wb_60_sum_w         -0.006556
# ws_30_p90_w         -0.007348
# wbdur_all_avg_w     -0.009768
# wbdur_all_p90_w     -0.038923
# ws_30_var_w         -0.106296
# strlen_30_var_w     -0.123098
# strdur_all_var_w    -0.126651
# dtype: float64
# Baseline accuracy on test data: 0.92
# Baseline accuracy on test data with features removed: 0.92
# Explained variance: [0.35855114 0.17205397 0.15054592 0.07406439 0.04804234 0.03854137
#  0.03815234 0.0337258  0.02424692 0.01777622]
# Cumulative: [0.35855114 0.53060511 0.68115103 0.75521542 0.80325776 0.84179913
#  0.87995147 0.91367727 0.93792419 0.9557004 ]
# Shape of Original Dataset: (693, 25)
# Shape after PCA: (693, 10)
# Optimal number of features: 16
# wb_all_sum_w, Selected False, Rank: 9
# walkdur_all_sum_w, Selected False, Rank: 6
# wbsteps_all_sum_w, Selected False, Rank: 10
# wbdur_all_avg_w, Selected True, Rank: 1
# wbdur_all_p90_w, Selected True, Rank: 1
# wbdur_all_var_w, Selected True, Rank: 1
# cadence_all_avg_w, Selected False, Rank: 8
# strdur_all_avg_w, Selected True, Rank: 1
# cadence_all_var_w, Selected False, Rank: 7
# strdur_all_var_w, Selected False, Rank: 5
# ws_1030_avg_w, Selected False, Rank: 2
# strlen_1030_avg_w, Selected True, Rank: 1
# wb_10_sum_w, Selected True, Rank: 1
# ws_10_p90_w, Selected True, Rank: 1
# wb_30_sum_w, Selected True, Rank: 1
# ws_30_avg_w, Selected True, Rank: 1
# strlen_30_avg_w, Selected True, Rank: 1
# cadence_30_avg_w, Selected True, Rank: 1
# strdur_30_avg_w, Selected True, Rank: 1
# ws_30_p90_w, Selected False, Rank: 4
# cadence_30_p90_w, Selected True, Rank: 1
# ws_30_var_w, Selected True, Rank: 1
# strlen_30_var_w, Selected False, Rank: 3
# wb_60_sum_w, Selected True, Rank: 1
# n_days_w, Selected True, Rank: 1
# >dt (693, 16)
# {'accuracy': 0.6926406926406926,
#  'precision': 0.1794871794871795,
#  'recall': 0.6666666666666666,
#  'f1': 0.2828282828282828,
#  'precision_macro': 0.5668677727501257,
#  'recall_macro': 0.680952380952381,
#  'f1_macro': 0.5436179981634527}
# Optimal number of features: 7
# wb_all_sum_w, Selected True, Rank: 1
# walkdur_all_sum_w, Selected False, Rank: 13
# wbsteps_all_sum_w, Selected True, Rank: 1
# wbdur_all_avg_w, Selected False, Rank: 2
# wbdur_all_p90_w, Selected True, Rank: 1
# wbdur_all_var_w, Selected True, Rank: 1
# cadence_all_avg_w, Selected False, Rank: 15
# strdur_all_avg_w, Selected False, Rank: 6
# cadence_all_var_w, Selected False, Rank: 18
# strdur_all_var_w, Selected False, Rank: 17
# ws_1030_avg_w, Selected False, Rank: 8
# strlen_1030_avg_w, Selected False, Rank: 7
# wb_10_sum_w, Selected False, Rank: 9
# ws_10_p90_w, Selected True, Rank: 1
# wb_30_sum_w, Selected False, Rank: 12
# ws_30_avg_w, Selected True, Rank: 1
# strlen_30_avg_w, Selected False, Rank: 14
# cadence_30_avg_w, Selected True, Rank: 1
# strdur_30_avg_w, Selected False, Rank: 11
# ws_30_p90_w, Selected False, Rank: 3
# cadence_30_p90_w, Selected False, Rank: 4
# ws_30_var_w, Selected False, Rank: 5
# strlen_30_var_w, Selected False, Rank: 10
# wb_60_sum_w, Selected False, Rank: 16
# n_days_w, Selected False, Rank: 19
# >rf (693, 7)
# {'accuracy': 0.6984126984126984,
#  'precision': 0.1853448275862069,
#  'recall': 0.6825396825396826,
#  'f1': 0.29152542372881357,
#  'precision_macro': 0.5709804398234722,
#  'recall_macro': 0.6912698412698413,
#  'f1_macro': 0.5499790271714645}
# Optimal number of features: 3
# wb_all_sum_w, Selected False, Rank: 11
# walkdur_all_sum_w, Selected False, Rank: 15
# wbsteps_all_sum_w, Selected False, Rank: 7
# wbdur_all_avg_w, Selected True, Rank: 1
# wbdur_all_p90_w, Selected False, Rank: 14
# wbdur_all_var_w, Selected False, Rank: 3
# cadence_all_avg_w, Selected False, Rank: 23
# strdur_all_avg_w, Selected False, Rank: 9
# cadence_all_var_w, Selected False, Rank: 22
# strdur_all_var_w, Selected False, Rank: 21
# ws_1030_avg_w, Selected False, Rank: 8
# strlen_1030_avg_w, Selected False, Rank: 4
# wb_10_sum_w, Selected True, Rank: 1
# ws_10_p90_w, Selected False, Rank: 17
# wb_30_sum_w, Selected False, Rank: 6
# ws_30_avg_w, Selected False, Rank: 5
# strlen_30_avg_w, Selected False, Rank: 13
# cadence_30_avg_w, Selected True, Rank: 1
# strdur_30_avg_w, Selected False, Rank: 20
# ws_30_p90_w, Selected False, Rank: 2
# cadence_30_p90_w, Selected False, Rank: 10
# ws_30_var_w, Selected False, Rank: 18
# strlen_30_var_w, Selected False, Rank: 16
# wb_60_sum_w, Selected False, Rank: 19
# n_days_w, Selected False, Rank: 12
# >gbm (693, 3)
# {'accuracy': 0.6897546897546898,
#  'precision': 0.17796610169491525,
#  'recall': 0.6666666666666666,
#  'f1': 0.2809364548494983,
#  'precision_macro': 0.5660071208693395,
#  'recall_macro': 0.6793650793650794,
#  'f1_macro': 0.5415721832665155}
# Results for BayesSearchCV: SVC for all 25 features
# {'accuracy': 0.6955266955266955,
#  'precision': 0.1991869918699187,
#  'recall': 0.7777777777777778,
#  'f1': 0.31715210355987056,
#  'precision_macro': 0.5839335406776887,
#  'recall_macro': 0.7325396825396826,
#  'f1_macro': 0.5606187630148471}
# Results from sequentially removing each feature from 25 features
# wb_all_sum_w          0.725397
# wb_60_sum_w           0.723810
# strlen_30_var_w       0.723016
# wb_30_sum_w           0.723016
# n_days_w              0.719841
# wb_10_sum_w           0.719841
# wbsteps_all_sum_w     0.719841
# walkdur_all_sum_w     0.716667
# strdur_all_avg_w      0.715873
# strdur_all_var_w      0.715873
# wbdur_all_p90_w       0.715079
# ws_30_var_w           0.711905
# wbdur_all_var_w       0.703968
# cadence_30_avg_w      0.701587
# cadence_30_p90_w      0.699206
# strdur_30_avg_w       0.698413
# ws_30_p90_w           0.697619
# cadence_all_var_w     0.697619
# ws_30_avg_w           0.695238
# cadence_all_avg_w     0.695238
# wbdur_all_avg_w       0.693651
# strlen_1030_avg_w     0.689683
# ws_10_p90_w           0.688095
# ws_1030_avg_w         0.676190
# strlen_30_avg_w       0.656349
# Removing wb_all_sum_w feature from data. recall_macro = 0.7253968253968255
# [[444 186]
#  [ 16  47]]
# Results from sequentially removing each feature from 24 features
# wb_10_sum_w           0.729365
# strdur_all_var_w      0.726984
# wb_60_sum_w           0.725397
# strlen_30_var_w       0.725397
# cadence_30_p90_w      0.722222
# wbdur_all_p90_w       0.720635
# strlen_1030_avg_w     0.715873
# n_days_w              0.715079
# wb_30_sum_w           0.713492
# wbdur_all_var_w       0.713492
# walkdur_all_sum_w     0.709524
# strdur_all_avg_w      0.708730
# cadence_30_avg_w      0.706349
# ws_30_p90_w           0.705556
# strlen_30_avg_w       0.703968
# wbsteps_all_sum_w     0.703175
# cadence_all_var_w     0.702381
# ws_30_var_w           0.695238
# wbdur_all_avg_w       0.695238
# cadence_all_avg_w     0.694444
# strdur_30_avg_w       0.691270
# ws_30_avg_w           0.686508
# ws_10_p90_w           0.675397
# ws_1030_avg_w         0.653968
# Removing wb_10_sum_w feature from data. recall_macro = 0.7293650793650793
# [[439 191]
#  [ 15  48]]
# Results from sequentially removing each feature from 23 features
# strlen_30_var_w       0.734921
# strdur_all_var_w      0.730159
# wb_30_sum_w           0.724603
# wbdur_all_p90_w       0.724603
# wb_60_sum_w           0.717460
# strlen_1030_avg_w     0.717460
# wbdur_all_avg_w       0.715079
# n_days_w              0.713492
# cadence_all_avg_w     0.711905
# ws_30_p90_w           0.711905
# wbsteps_all_sum_w     0.708730
# ws_30_var_w           0.707937
# cadence_30_avg_w      0.707937
# strdur_all_avg_w      0.705556
# wbdur_all_var_w       0.705556
# ws_10_p90_w           0.704762
# walkdur_all_sum_w     0.704762
# strdur_30_avg_w       0.703175
# strlen_30_avg_w       0.700794
# ws_1030_avg_w         0.699206
# cadence_30_p90_w      0.698413
# ws_30_avg_w           0.694444
# cadence_all_var_w     0.692857
# Removing strlen_30_var_w feature from data. recall_macro = 0.734920634920635
# [[436 194]
#  [ 14  49]]
# Results from sequentially removing each feature from 22 features
# n_days_w              0.734921
# cadence_all_avg_w     0.732540
# wb_60_sum_w           0.730952
# strdur_all_avg_w      0.723810
# wbdur_all_var_w       0.723810
# wb_30_sum_w           0.722222
# strlen_1030_avg_w     0.716667
# cadence_30_avg_w      0.715079
# cadence_all_var_w     0.714286
# wbdur_all_avg_w       0.711111
# strdur_all_var_w      0.710317
# ws_1030_avg_w         0.707937
# wbdur_all_p90_w       0.707143
# ws_30_var_w           0.704762
# strlen_30_avg_w       0.701587
# wbsteps_all_sum_w     0.700000
# strdur_30_avg_w       0.698413
# walkdur_all_sum_w     0.698413
# ws_30_p90_w           0.692857
# cadence_30_p90_w      0.691270
# ws_10_p90_w           0.684127
# ws_30_avg_w           0.666667
# Removing n_days_w feature from data. recall_macro = 0.734920634920635
# [[436 194]
#  [ 14  49]]
# Results from sequentially removing each feature from 21 features
# cadence_all_avg_w     0.723016
# cadence_30_p90_w      0.722222
# wbdur_all_avg_w       0.722222
# wb_60_sum_w           0.721429
# cadence_30_avg_w      0.720635
# walkdur_all_sum_w     0.712698
# ws_10_p90_w           0.707937
# strdur_all_avg_w      0.707143
# wbdur_all_p90_w       0.706349
# wb_30_sum_w           0.703968
# strdur_all_var_w      0.703175
# wbsteps_all_sum_w     0.702381
# wbdur_all_var_w       0.699206
# strlen_1030_avg_w     0.696032
# ws_30_var_w           0.694444
# ws_1030_avg_w         0.692857
# strlen_30_avg_w       0.690476
# strdur_30_avg_w       0.688889
# ws_30_p90_w           0.687302
# cadence_all_var_w     0.684127
# ws_30_avg_w           0.682540
# Removing cadence_all_avg_w feature from data. recall_macro = 0.723015873015873
# [[441 189]
#  [ 16  47]]
# Results from sequentially removing each feature from 20 features
# wbdur_all_avg_w       0.722222
# ws_30_p90_w           0.720635
# ws_30_var_w           0.717460
# cadence_30_avg_w      0.716667
# strlen_1030_avg_w     0.715079
# strdur_all_avg_w      0.711905
# ws_10_p90_w           0.710317
# cadence_30_p90_w      0.710317
# ws_30_avg_w           0.708730
# wbdur_all_p90_w       0.707143
# ws_1030_avg_w         0.705556
# wb_30_sum_w           0.703968
# wbsteps_all_sum_w     0.702381
# wbdur_all_var_w       0.700000
# strlen_30_avg_w       0.699206
# walkdur_all_sum_w     0.695238
# strdur_all_var_w      0.694444
# cadence_all_var_w     0.692857
# strdur_30_avg_w       0.684127
# wb_60_sum_w           0.678571
# Removing wbdur_all_avg_w feature from data. recall_macro = 0.7222222222222222
# [[440 190]
#  [ 16  47]]
# Results from sequentially removing each feature from 19 features
# cadence_30_avg_w      0.715873
# cadence_30_p90_w      0.710317
# strdur_all_avg_w      0.703175
# strlen_30_avg_w       0.701587
# wb_30_sum_w           0.699206
# wbsteps_all_sum_w     0.698413
# ws_10_p90_w           0.697619
# wb_60_sum_w           0.696825
# wbdur_all_var_w       0.694444
# cadence_all_var_w     0.693651
# ws_30_avg_w           0.692857
# ws_1030_avg_w         0.689683
# wbdur_all_p90_w       0.688889
# strdur_30_avg_w       0.687302
# strlen_1030_avg_w     0.686508
# walkdur_all_sum_w     0.686508
# ws_30_var_w           0.685714
# ws_30_p90_w           0.679365
# strdur_all_var_w      0.665873
# Removing cadence_30_avg_w feature from data. recall_macro = 0.7158730158730159
# [[432 198]
#  [ 16  47]]
# Results from sequentially removing each feature from 18 features
# ws_1030_avg_w         0.723016
# strlen_30_avg_w       0.720635
# ws_30_var_w           0.717460
# ws_30_p90_w           0.715873
# wbdur_all_p90_w       0.715873
# strdur_all_var_w      0.714286
# strdur_30_avg_w       0.714286
# cadence_all_var_w     0.714286
# ws_10_p90_w           0.711905
# cadence_30_p90_w      0.711111
# walkdur_all_sum_w     0.707143
# wb_60_sum_w           0.705556
# strlen_1030_avg_w     0.703968
# wbdur_all_var_w       0.697619
# wb_30_sum_w           0.696032
# strdur_all_avg_w      0.688095
# wbsteps_all_sum_w     0.681746
# ws_30_avg_w           0.677778
# Removing ws_1030_avg_w feature from data. recall_macro = 0.723015873015873
# [[421 209]
#  [ 14  49]]
# Results from sequentially removing each feature from 17 features
# wbdur_all_p90_w       0.728571
# wbdur_all_var_w       0.718254
# wb_30_sum_w           0.712698
# ws_30_p90_w           0.710317
# strlen_30_avg_w       0.708730
# wb_60_sum_w           0.700794
# strdur_all_avg_w      0.700794
# ws_10_p90_w           0.700000
# cadence_all_var_w     0.696825
# ws_30_var_w           0.696032
# strdur_all_var_w      0.692063
# wbsteps_all_sum_w     0.692063
# strlen_1030_avg_w     0.688889
# strdur_30_avg_w       0.685714
# ws_30_avg_w           0.684127
# cadence_30_p90_w      0.676190
# walkdur_all_sum_w     0.669841
# Removing wbdur_all_p90_w feature from data. recall_macro = 0.7285714285714285
# [[418 212]
#  [ 13  50]]
# Results from sequentially removing each feature from 16 features
# ws_30_p90_w           0.721429
# strlen_1030_avg_w     0.718254
# wbsteps_all_sum_w     0.717460
# ws_30_var_w           0.716667
# strdur_30_avg_w       0.711905
# wb_30_sum_w           0.711111
# ws_10_p90_w           0.707143
# wbdur_all_var_w       0.703968
# walkdur_all_sum_w     0.702381
# cadence_all_var_w     0.699206
# strdur_all_var_w      0.689683
# strlen_30_avg_w       0.688095
# wb_60_sum_w           0.681746
# ws_30_avg_w           0.679365
# strdur_all_avg_w      0.676984
# cadence_30_p90_w      0.660317
# Removing ws_30_p90_w feature from data. recall_macro = 0.7214285714285714
# [[419 211]
#  [ 14  49]]
# Results from sequentially removing each feature from 15 features
# strdur_all_var_w      0.714286
# walkdur_all_sum_w     0.711111
# ws_10_p90_w           0.707143
# strlen_1030_avg_w     0.707143
# wb_60_sum_w           0.705556
# ws_30_var_w           0.705556
# wb_30_sum_w           0.702381
# cadence_all_var_w     0.701587
# wbdur_all_var_w       0.701587
# strlen_30_avg_w       0.694444
# wbsteps_all_sum_w     0.688095
# ws_30_avg_w           0.687302
# cadence_30_p90_w      0.683333
# strdur_all_avg_w      0.683333
# strdur_30_avg_w       0.665079
# Removing strdur_all_var_w feature from data. recall_macro = 0.7142857142857143
# [[410 220]
#  [ 14  49]]
# Results from sequentially removing each feature from 14 features
# strdur_all_avg_w      0.715873
# ws_30_avg_w           0.706349
# wbdur_all_var_w       0.703968
# wb_30_sum_w           0.693651
# walkdur_all_sum_w     0.688095
# strlen_30_avg_w       0.684127
# strdur_30_avg_w       0.680159
# wbsteps_all_sum_w     0.678571
# ws_30_var_w           0.676984
# cadence_all_var_w     0.674603
# cadence_30_p90_w      0.670635
# ws_10_p90_w           0.665079
# wb_60_sum_w           0.662698
# strlen_1030_avg_w     0.638095
# Removing strdur_all_avg_w feature from data. recall_macro = 0.7158730158730159
# [[432 198]
#  [ 16  47]]
# Results from sequentially removing each feature from 13 features
# wb_60_sum_w           0.718254
# wb_30_sum_w           0.707937
# walkdur_all_sum_w     0.707143
# ws_30_var_w           0.705556
# wbsteps_all_sum_w     0.700000
# cadence_all_var_w     0.699206
# ws_30_avg_w           0.693651
# wbdur_all_var_w       0.687302
# strlen_30_avg_w       0.686508
# strdur_30_avg_w       0.680159
# cadence_30_p90_w      0.675397
# strlen_1030_avg_w     0.673810
# ws_10_p90_w           0.657143
# Removing wb_60_sum_w feature from data. recall_macro = 0.7182539682539683
# [[425 205]
#  [ 15  48]]
# Results from sequentially removing each feature from 12 features
# wbsteps_all_sum_w     0.721429
# cadence_all_var_w     0.717460
# ws_10_p90_w           0.715873
# wbdur_all_var_w       0.712698
# ws_30_var_w           0.708730
# walkdur_all_sum_w     0.707937
# wb_30_sum_w           0.705556
# strdur_30_avg_w       0.703175
# strlen_1030_avg_w     0.693651
# ws_30_avg_w           0.688889
# strlen_30_avg_w       0.680159
# cadence_30_p90_w      0.678571
# Removing wbsteps_all_sum_w feature from data. recall_macro = 0.7214285714285714
# [[439 191]
#  [ 16  47]]
# Results from sequentially removing each feature from 11 features
# cadence_all_var_w     0.711905
# wb_30_sum_w           0.692063
# ws_30_var_w           0.690476
# walkdur_all_sum_w     0.689683
# ws_10_p90_w           0.680952
# strlen_30_avg_w       0.677778
# cadence_30_p90_w      0.676190
# wbdur_all_var_w       0.676190
# strlen_1030_avg_w     0.673810
# strdur_30_avg_w       0.671429
# ws_30_avg_w           0.668254
# Removing cadence_all_var_w feature from data. recall_macro = 0.7119047619047619
# [[447 183]
#  [ 18  45]]
# Results from sequentially removing each feature from 10 features
# walkdur_all_sum_w     0.703968
# wb_30_sum_w           0.692063
# ws_10_p90_w           0.690476
# ws_30_var_w           0.684921
# ws_30_avg_w           0.684921
# strlen_30_avg_w       0.675397
# cadence_30_p90_w      0.670635
# strlen_1030_avg_w     0.670635
# wbdur_all_var_w       0.670635
# strdur_30_avg_w       0.657937
# Removing walkdur_all_sum_w feature from data. recall_macro = 0.7039682539682539
# [[447 183]
#  [ 19  44]]
# Results from sequentially removing each feature from 9 features
# wb_30_sum_w           0.697619
# ws_30_avg_w           0.688889
# strlen_1030_avg_w     0.687302
# strlen_30_avg_w       0.685714
# strdur_30_avg_w       0.680952
# ws_30_var_w           0.673016
# ws_10_p90_w           0.667460
# cadence_30_p90_w      0.666667
# wbdur_all_var_w       0.656349
# Removing wb_30_sum_w feature from data. recall_macro = 0.6976190476190476
# [[439 191]
#  [ 19  44]]
# Results from sequentially removing each feature from 8 features
# ws_10_p90_w           0.693651
# ws_30_var_w           0.688095
# ws_30_avg_w           0.685714
# strlen_30_avg_w       0.680952
# wbdur_all_var_w       0.676984
# strdur_30_avg_w       0.675397
# cadence_30_p90_w      0.673810
# strlen_1030_avg_w     0.661905
# Removing ws_10_p90_w feature from data. recall_macro = 0.6936507936507936
# [[454 176]
#  [ 21  42]]
# Results from sequentially removing each feature from 7 features
# ws_30_var_w           0.703968
# ws_30_avg_w           0.692857
# strdur_30_avg_w       0.692063
# strlen_30_avg_w       0.688095
# strlen_1030_avg_w     0.677778
# wbdur_all_var_w       0.673810
# cadence_30_p90_w      0.673016
# Removing ws_30_var_w feature from data. recall_macro = 0.7039682539682539
# [[417 213]
#  [ 16  47]]
# Results from sequentially removing each feature from 6 features
# ws_30_avg_w           0.705556
# strlen_30_avg_w       0.700794
# wbdur_all_var_w       0.684127
# strdur_30_avg_w       0.682540
# strlen_1030_avg_w     0.679365
# cadence_30_p90_w      0.665079
# Removing ws_30_avg_w feature from data. recall_macro = 0.7055555555555555
# [[439 191]
#  [ 18  45]]
# Results from sequentially removing each feature from 5 features
# strlen_1030_avg_w     0.696032
# wbdur_all_var_w       0.677778
# strlen_30_avg_w       0.674603
# cadence_30_p90_w      0.673016
# strdur_30_avg_w       0.649206
# Removing strlen_1030_avg_w feature from data. recall_macro = 0.696031746031746
# [[437 193]
#  [ 19  44]]
# Results from sequentially removing each feature from 4 features
# strdur_30_avg_w      0.693651
# strlen_30_avg_w      0.683333
# wbdur_all_var_w      0.676984
# cadence_30_p90_w     0.653968
# Removing strdur_30_avg_w feature from data. recall_macro = 0.6936507936507936
# [[424 206]
#  [ 18  45]]
# Results from sequentially removing each feature from 3 features
# strlen_30_avg_w      0.711111
# wbdur_all_var_w      0.696032
# cadence_30_p90_w     0.611905
# Removing strlen_30_avg_w feature from data. recall_macro = 0.7111111111111111
# [[446 184]
#  [ 18  45]]
# Results from sequentially removing each feature from 2 features
# wbdur_all_var_w      0.694444
# cadence_30_p90_w     0.576190
# Removing wbdur_all_var_w feature from data. recall_macro = 0.6944444444444444
# [[445 185]
#  [ 20  43]]
# Best feature set (size=23): ['walkdur_all_sum_w' 'wbsteps_all_sum_w' 'wbdur_all_avg_w'
#  'wbdur_all_p90_w' 'wbdur_all_var_w' 'cadence_all_avg_w'
#  'strdur_all_avg_w' 'cadence_all_var_w' 'strdur_all_var_w' 'ws_1030_avg_w'
#  'strlen_1030_avg_w' 'ws_10_p90_w' 'wb_30_sum_w' 'ws_30_avg_w'
#  'strlen_30_avg_w' 'cadence_30_avg_w' 'strdur_30_avg_w' 'ws_30_p90_w'
#  'cadence_30_p90_w' 'ws_30_var_w' 'strlen_30_var_w' 'wb_60_sum_w'
#  'n_days_w']
# Best score: 0.734920634920635
# Feature selection: None
# X_data shape: (693, 25)

# %%
######################################################################
# TEST Classification / Prediction
# Note this needs to be tidied up into the experimentation framework
######################################################################

#import faulthandler
#import signal

#faulthandler.register(signal.SIGINT.value) # I'm not sure what this was doing but it wasn't working for me


# train test split
X_train, X_test, y_train, y_test = (
    train_test_split(X_data, y_data, stratify=y_data, test_size=0.2, random_state=42))

# scale the data
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# sample weighting
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train)

model = svm_model

model.fit(X_train, y_train, sample_weight=sample_weights)
# Print the best parameters
print(f"Best Parameters: {model.best_params_}")
print(f"Best Score: {model.best_score_}")
#model = model.best_estimator_  # gets the best estimator so we're not doing bayesian searching again on each fold
show_evaluation(model, X_test, y_test)

# Annoyingly cross_val_score and cross_val_predict can differ ???
conf_mat, actual, predicted = do_cv(model, X_data, y_data)
display(get_metrics_from_prediction(actual, predicted))
display_cm(conf_mat)
# Out:
# Best Parameters: OrderedDict({'C': 643.1854566491933, 'degree': 5, 'gamma': 1.3971732124886836e-05, 'kernel': 'rbf'})
# Best Score: 0.7301485148514846
# accuracy: 0.66
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.66      0.78       126
#            1       0.17      0.69      0.28        13
#
#     accuracy                           0.66       139
#    macro avg       0.56      0.68      0.53       139
# weighted avg       0.88      0.66      0.73       139
# Fold 0
# accuracy: 0.73
# precision_macro: 0.62
# recall_macro: 0.82
# f1_macro: 0.61
# Fold 1
# accuracy: 0.72
# precision_macro: 0.56
# recall_macro: 0.64
# f1_macro: 0.55
# Fold 2
# accuracy: 0.69
# precision_macro: 0.61
# recall_macro: 0.79
# f1_macro: 0.58
# Fold 3
# accuracy: 0.70
# precision_macro: 0.59
# recall_macro: 0.76
# f1_macro: 0.57
# Fold 4
# accuracy: 0.63
# precision_macro: 0.55
# recall_macro: 0.65
# f1_macro: 0.50
# {'accuracy': 0.6955266955266955,
#  'precision': 0.1991869918699187,
#  'recall': 0.7777777777777778,
#  'f1': 0.31715210355987056,
#  'precision_macro': 0.5839335406776887,
#  'recall_macro': 0.7325396825396826,
#  'f1_macro': 0.5606187630148471}

# %%
######################################################################
# Resampling data (NOT USED)
# Note this needs to be tidied up into the experimentation framework
######################################################################


def get_unsampled(x_data, x_sampled, y_data):
    # Create dataframe with column showing whether data has been sampled or not
    # Shown by column "_merge" value "both" == sampled "left_only" == not sampled
    merged = x_data.merge(x_sampled.drop_duplicates(), how='left', indicator=True)
    # Get indices of rows which have not been sampled
    unsampled_indices = merged.index[merged['_merge'] == "left_only"].tolist()
    X_unsampled = X_data.iloc[unsampled_indices]
    y_unsampled = y_data.iloc[unsampled_indices]
    return X_unsampled, y_unsampled


if (do_data_sampling):
    rus = RandomUnderSampler(random_state=42)
    ros = RandomOverSampler(random_state=42)
    smote = SMOTE(random_state=42)
    adasyn = ADASYN(random_state=42)

    X_data, y_data = smote.fit_resample(X_data, y_data)

# %%
# all models in one dict with names
models_dict = {
    "SVM": svm_model,
    "MLP": mlp_model,
    "KNN": knn_model,
    "XGBoost": xgb_model,
    "Random Forest": rf_model,
    "Decision Tree": dt_model,
    "Logistic Regression": lr_model
}

model_performance = []

for name, model in models_dict.items():
    if not name == "KNN":
        model.fit(X_train, y_train, sample_weight=sample_weights)
    else:
        model.fit(X_train, y_train)

    print(f"Best Parameters: {model.best_params_}")
    print(f"Best Score: {model.best_score_}")
    show_evaluation(model, X_test, y_test)

    conf_mat, actual, predicted = do_cv(model, X_data, y_data)
    metrics = get_metrics_from_prediction(actual, predicted)
    metrics["Model"] = name
    model_performance.append(metrics)
    save_name = name+" Confusion Matrix"
    display_cm(conf_mat, save_name)

performance_df = pd.DataFrame(model_performance)
cols = ['Model'] + [c for c in performance_df.columns if c != 'Model']
performance_df = performance_df[cols]
performance_df.set_index('Model', inplace=True)
performance_df = performance_df.sort_values(by=scoring, ascending=False)
performance_df.to_csv(fig_save_dir + "test_performance.csv")
display(performance_df)
# Out:
# Best Parameters: OrderedDict({'C': 643.1854566491933, 'degree': 5, 'gamma': 1.3971732124886836e-05, 'kernel': 'rbf'})
# Best Score: 0.7301485148514846
# accuracy: 0.66
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.66      0.78       126
#            1       0.17      0.69      0.28        13
#
#     accuracy                           0.66       139
#    macro avg       0.56      0.68      0.53       139
# weighted avg       0.88      0.66      0.73       139
# Fold 0
# accuracy: 0.73
# precision_macro: 0.62
# recall_macro: 0.82
# f1_macro: 0.61
# Fold 1
# accuracy: 0.72
# precision_macro: 0.56
# recall_macro: 0.64
# f1_macro: 0.55
# Fold 2
# accuracy: 0.69
# precision_macro: 0.61
# recall_macro: 0.79
# f1_macro: 0.58
# Fold 3
# accuracy: 0.70
# precision_macro: 0.59
# recall_macro: 0.76
# f1_macro: 0.57
# Fold 4
# accuracy: 0.63
# precision_macro: 0.55
# recall_macro: 0.65
# f1_macro: 0.50
# Best Parameters: OrderedDict({'activation': 'relu', 'alpha': 4.869521028037488e-05, 'hidden_layer_sizes': 77, 'learning_rate': 'adaptive', 'learning_rate_init': 0.003708147357379244, 'solver': 'sgd'})
# Best Score: 0.6958613861386136
# accuracy: 0.68
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.68      0.80       126
#            1       0.18      0.69      0.29        13
#
#     accuracy                           0.68       139
#    macro avg       0.57      0.69      0.54       139
# weighted avg       0.88      0.68      0.75       139
# Fold 0
# accuracy: 0.74
# precision_macro: 0.59
# recall_macro: 0.72
# f1_macro: 0.59
# Fold 1
# accuracy: 0.68
# precision_macro: 0.55
# recall_macro: 0.62
# f1_macro: 0.52
# Fold 2
# accuracy: 0.71
# precision_macro: 0.60
# recall_macro: 0.77
# f1_macro: 0.58
# Fold 3
# accuracy: 0.72
# precision_macro: 0.57
# recall_macro: 0.70
# f1_macro: 0.56
# Fold 4
# accuracy: 0.60
# precision_macro: 0.53
# recall_macro: 0.59
# f1_macro: 0.47
# Best Parameters: OrderedDict({'algorithm': 'kd_tree', 'leaf_size': 23, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'})
# Best Score: 0.5662970297029702
# accuracy: 0.86
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       126
#            1       0.20      0.15      0.17        13
#
#     accuracy                           0.86       139
#    macro avg       0.56      0.55      0.55       139
# weighted avg       0.85      0.86      0.86       139
# Sample weighting not accepted, training without...
# KNeighborsClassifier.fit() got an unexpected keyword argument 'sample_weight'
# Fold 0
# accuracy: 0.88
# precision_macro: 0.61
# recall_macro: 0.59
# f1_macro: 0.60
# Sample weighting not accepted, training without...
# KNeighborsClassifier.fit() got an unexpected keyword argument 'sample_weight'
# Fold 1
# accuracy: 0.84
# precision_macro: 0.50
# recall_macro: 0.50
# f1_macro: 0.50
# Sample weighting not accepted, training without...
# KNeighborsClassifier.fit() got an unexpected keyword argument 'sample_weight'
# Fold 2
# accuracy: 0.89
# precision_macro: 0.65
# recall_macro: 0.60
# f1_macro: 0.61
# Sample weighting not accepted, training without...
# KNeighborsClassifier.fit() got an unexpected keyword argument 'sample_weight'
# Fold 3
# accuracy: 0.87
# precision_macro: 0.59
# recall_macro: 0.59
# f1_macro: 0.59
# Sample weighting not accepted, training without...
# KNeighborsClassifier.fit() got an unexpected keyword argument 'sample_weight'
# Fold 4
# accuracy: 0.90
# precision_macro: 0.65
# recall_macro: 0.61
# f1_macro: 0.62
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:32:00] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best Parameters: OrderedDict({'colsample_bytree': 1.0, 'gamma': 4.999999999999999, 'learning_rate': 0.021671791867067546, 'max_depth': 3, 'n_estimators': 298, 'reg_alpha': 10.0, 'reg_lambda': 1e-05, 'subsample': 1.0})
# Best Score: 0.6850891089108906
# accuracy: 0.62
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.62      0.75       126
#            1       0.14      0.62      0.23        13
#
#     accuracy                           0.62       139
#    macro avg       0.54      0.62      0.49       139
# weighted avg       0.87      0.62      0.70       139
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:32:25] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Fold 0
# accuracy: 0.73
# precision_macro: 0.56
# recall_macro: 0.64
# f1_macro: 0.55
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:32:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Fold 1
# accuracy: 0.78
# precision_macro: 0.59
# recall_macro: 0.67
# f1_macro: 0.59
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:33:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Fold 2
# accuracy: 0.68
# precision_macro: 0.59
# recall_macro: 0.76
# f1_macro: 0.56
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:33:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Fold 3
# accuracy: 0.84
# precision_macro: 0.53
# recall_macro: 0.54
# f1_macro: 0.53
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:34:20] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Fold 4
# accuracy: 0.76
# precision_macro: 0.52
# recall_macro: 0.53
# f1_macro: 0.51
# Best Parameters: OrderedDict({'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 20, 'n_estimators': 500})
# Best Score: 0.6527425742574254
# accuracy: 0.71
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82       126
#            1       0.13      0.38      0.20        13
#
#     accuracy                           0.71       139
#    macro avg       0.53      0.56      0.51       139
# weighted avg       0.85      0.71      0.76       139
# Fold 0
# accuracy: 0.78
# precision_macro: 0.57
# recall_macro: 0.64
# f1_macro: 0.57
# Fold 1
# accuracy: 0.79
# precision_macro: 0.54
# recall_macro: 0.57
# f1_macro: 0.55
# Fold 2
# accuracy: 0.71
# precision_macro: 0.50
# recall_macro: 0.49
# f1_macro: 0.48
# Fold 3
# accuracy: 0.83
# precision_macro: 0.53
# recall_macro: 0.53
# f1_macro: 0.53
# Fold 4
# accuracy: 0.62
# precision_macro: 0.52
# recall_macro: 0.57
# f1_macro: 0.47
# Best Parameters: OrderedDict({'ccp_alpha': 0.09554779863099283, 'criterion': 'entropy', 'max_depth': 27, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 6})
# Best Score: 0.7234752475247519
# accuracy: 0.55
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.52      0.68       126
#            1       0.14      0.77      0.24        13
#
#     accuracy                           0.55       139
#    macro avg       0.55      0.65      0.46       139
# weighted avg       0.88      0.55      0.64       139
# Fold 0
# accuracy: 0.73
# precision_macro: 0.59
# recall_macro: 0.72
# f1_macro: 0.58
# Fold 1
# accuracy: 0.71
# precision_macro: 0.57
# recall_macro: 0.67
# f1_macro: 0.55
# Fold 2
# accuracy: 0.61
# precision_macro: 0.56
# recall_macro: 0.68
# f1_macro: 0.50
# Fold 3
# accuracy: 0.71
# precision_macro: 0.56
# recall_macro: 0.65
# f1_macro: 0.54
# Fold 4
# accuracy: 0.58
# precision_macro: 0.56
# recall_macro: 0.69
# f1_macro: 0.48
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Best Parameters: OrderedDict({'C': 5607.275056505338, 'fit_intercept': True, 'l1_ratio': 0.598047077512128, 'penalty': 'elasticnet'})
# Best Score: 0.7028514851485145
# accuracy: 0.69
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.70      0.80       126
#            1       0.17      0.62      0.27        13
#
#     accuracy                           0.69       139
#    macro avg       0.56      0.66      0.54       139
# weighted avg       0.87      0.69      0.75       139
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Fold 0
# accuracy: 0.73
# precision_macro: 0.62
# recall_macro: 0.81
# f1_macro: 0.61
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Fold 1
# accuracy: 0.73
# precision_macro: 0.55
# recall_macro: 0.61
# f1_macro: 0.54
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Fold 2
# accuracy: 0.68
# precision_macro: 0.58
# recall_macro: 0.72
# f1_macro: 0.55
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\sklearn\linear_model\_logistic.py:1152: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\sklearn\linear_model\_logistic.py:1160: UserWarning: Inconsistent values: penalty=l2 with l1_ratio=0.10485915855270359. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Fold 3
# accuracy: 0.75
# precision_macro: 0.57
# recall_macro: 0.68
# f1_macro: 0.57
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\sklearn\linear_model\_logistic.py:1152: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\ac4jmi\anaconda3\envs\mobgap_fixed\Lib\site-packages\sklearn\linear_model\_logistic.py:1160: UserWarning: Inconsistent values: penalty=l2 with l1_ratio=0.871651928463215. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# Fold 4
# accuracy: 0.69
# precision_macro: 0.55
# recall_macro: 0.64
# f1_macro: 0.52
#                      accuracy  precision    recall        f1  precision_macro  \
# Model
# SVM                  0.695527   0.199187  0.777778  0.317152         0.583934
# Logistic Regression  0.717172   0.193548  0.666667  0.300000         0.574715
# Decision Tree        0.669553   0.173228  0.698413  0.277603         0.564974
# MLP                  0.691198   0.178723  0.666667  0.281879         0.566436
# XGBoost              0.759019   0.182927  0.476190  0.264317         0.560272
# KNN                  0.875902   0.265306  0.206349  0.232143         0.593833
# Random Forest        0.746032   0.135484  0.333333  0.192661         0.528708
#
#                      recall_macro  f1_macro
# Model
# SVM                      0.732540  0.560619
# Logistic Regression      0.694444  0.561392
# Decision Tree            0.682540  0.531692
# MLP                      0.680159  0.542594
# XGBoost                  0.631746  0.560114
# KNN                      0.574603  0.582319
# Random Forest            0.560317  0.520988

# %%
# un-normalise the data and try to find out which samples were misclassified
best_model_name = performance_df.sort_values(by=scoring, ascending=False).iloc[0].name
print(best_model_name)
best_model = models_dict[best_model_name]

if not best_model_name == "KNN":
    best_model.fit(X_train, y_train, sample_weight=sample_weights)
else:
    best_model.fit(X_train, y_train)

train_predictions = best_model.predict(X_train)
test_predictions = best_model.predict(X_test)

indexed_train_predictions = y_train.reset_index()
indexed_train_predictions["Prediction"] = train_predictions
indexed_train_predictions.index = indexed_train_predictions["index"]
indexed_train_predictions = indexed_train_predictions.drop(["index"], axis=1)

indexed_test_predictions = y_test.reset_index()
indexed_test_predictions["Prediction"] = test_predictions
indexed_test_predictions.index = indexed_test_predictions["index"]
indexed_test_predictions = indexed_test_predictions.drop(["index"], axis=1)

predictions_to_be_appended = pd.concat([indexed_train_predictions, indexed_test_predictions], axis=0)
#predictions_to_be_appended = indexed_test_predictions
predictions_to_be_appended["misclassified"] = abs(
    predictions_to_be_appended["Prediction"] - predictions_to_be_appended["progression"])
predictions_to_be_appended["correctly_classified"] = 1 - predictions_to_be_appended["misclassified"]
predictions_to_be_appended = predictions_to_be_appended.drop(["progression"], axis=1)

original_data_with_predictions = labels_X_all.join(predictions_to_be_appended)

display(original_data_with_predictions[original_data_with_predictions["misclassified"] == 1].head(5))
original_data_with_predictions.to_csv(fig_save_dir + "predictions.csv")
# Out:
# SVM
#     Local.Participant visit.number   age  gender  EDFSCR1L  time_since_diag  \
# 0               10378           T5  52.0       1       4.5      258543415.0
# 2               10379           T3  37.0       0       4.5      150108694.0
# 11              10385           T4  41.0       0       6.0      304599632.0
# 13              10386           T3  48.0       1       4.5      651838582.0
# 16              10389           T2  44.0       1       4.5      484571225.0
#
#     time_since_onset  Prev_EDSS Prev_Timepoint  progression  ...  \
# 0       2.604442e+08        4.5             T4            0  ...
# 2       5.631871e+08        4.5             T2            0  ...
# 11      3.656844e+08        4.5             T3            1  ...
# 13      1.168165e+09        4.5             T2            0  ...
# 16      4.848304e+08        4.0             T1            0  ...
#
#     strdur_30_avg_w  ws_30_p90_w  cadence_30_p90_w  ws_30_var_w  \
# 0              1.22         0.69              97.0         22.0
# 2              1.28         1.10              99.0         23.0
# 11             1.16         1.12             109.0         18.0
# 13             1.24         0.88             107.0         11.0
# 16             1.24         0.98             105.0         17.0
#
#     strlen_30_var_w  wb_60_sum_w  n_days_w  Prediction  misclassified  \
# 0              15.0          0.0       7.0           1              1
# 2              17.0          9.0       5.0           1              1
# 11             14.0         10.0       7.0           0              1
# 13              7.0          2.0       7.0           1              1
# 16             13.0          1.0       7.0           1              1
#
#     correctly_classified
# 0                      0
# 2                      0
# 11                     0
# 13                     0
# 16                     0
#
# [5 rows x 38 columns]

# %%
scores = sorted(list(set(original_data_with_predictions['Prev_EDSS']).union(
    set(original_data_with_predictions['EDFSCR1L']))))

error_matrix = original_data_with_predictions.pivot_table(
    index='Prev_EDSS',
    columns='EDFSCR1L',
    values='misclassified',
    aggfunc='sum',
    fill_value=0
).reindex(index=scores, columns=scores, fill_value=0)

total_matrix = original_data_with_predictions.pivot_table(
    index='Prev_EDSS',
    columns='EDFSCR1L',
    values='Prediction',  # Any column works here for counting
    aggfunc='count',
    fill_value=0
).reindex(index=scores, columns=scores, fill_value=0)

percentage_matrix = (error_matrix / total_matrix) * 100
percentage_matrix = percentage_matrix.fillna(0)  # Clean up NaNs where total was 0

annot_labels = np.array([
    [f"{int(count)}\\{int(total)}\n({pct:.1f}%)" if total > 0 else ""
     for count, pct, total in zip(count_row, pct_row, total_row)]
    for count_row, pct_row, total_row in zip(error_matrix.values, percentage_matrix.values, total_matrix.values)
])

mask = (total_matrix == 0)

plt.figure(figsize=(12, 10))

sns.heatmap(
    percentage_matrix,
    annot=annot_labels,
    fmt='',
    mask=mask,
    cmap="YlOrRd",
    cbar_kws={'label': 'Percentage Misclassified (%)'},
    linewidths=.5,
    linecolor='whitesmoke'
)

if drop_DMO_features:
    app_str = "(DMO Features Excluded)"
    sav_str = "_no_dmo_features"
elif drop_non_DMO_features:
    app_str = "(Demographic Features Excluded)"
    save_str = "_dmo_features"
else:
    app_str = "(No Features Excluded)"
    sav_str = "_all_features"

plt.title('EDSS Transition Misclassification Rates ' + app_str)
plt.xlabel('Next EDSS')
plt.ylabel('Previous EDSS')
plt.savefig(fig_save_dir + "misclassifications_" + best_model_name + sav_str + ".png")
plt.show()

# %%
sns.set_style("ticks")
sns.set_context("paper", font_scale=1.4)

prog_group = original_data_with_predictions[original_data_with_predictions["progression"] == 1]
no_prog_group = original_data_with_predictions[original_data_with_predictions["progression"] == 0]

feature_cols = [c for c in original_data_with_predictions.columns if c != "progression"]

for col in feature_cols:
    plt.figure(figsize=(6, 4))

    if pd.api.types.is_numeric_dtype(original_data_with_predictions[col]):

        sns.kdeplot(data=no_prog_group, x=col, fill=True,
                    color='forestgreen', label='No Progression', alpha=0.3, linewidth=2)
        sns.kdeplot(data=prog_group, x=col, fill=True,
                    color='crimson', label='Progression', alpha=0.4, linewidth=2)

        plt.ylabel('Density')
        plt.legend()

    else:
        temp_df = original_data_with_predictions.groupby('progression')[col].value_counts(normalize=True).rename(
            'proportion').reset_index()
        temp_df['progression_label'] = temp_df['progression'].map({0: 'No Progression', 1: 'Progression'})

        sns.barplot(data=temp_df, x=col, y='proportion', hue='progression_label',
                    palette={'No Progression': 'forestgreen', 'Progression': 'crimson'}, edgecolor='black')

        plt.ylabel('Proportion')
        plt.legend(title=None)

    plt.title(f'{col}')
    plt.xlabel(col)

    sns.despine()

    plt.tight_layout()
    plt.show()

# %%
# correlate walking aid use with dmos and demographics
